# %% [markdown]
# # Lab 01: Data wrangling and EDA
#
# **You should add this to a personal Github repo and submit the link to the repo in Canvas.** Add your name to the top of this document and anyone you worked with.
#
# The goal of this lab is to practice working with datasets using Pandas and explore a dataset with plotting and basic statistics. In particular, we will look at a plot to track flows (association between two categoricals): the alluvial diagram.
#
# Here is your lab prompt: You are advising the University of Virginia’s Office of Development on opportunities to expand philanthropic support from international sources. Using the foreign-giving data provided, develop a short strategic plan identifying the countries, institutions, or donor segments UVA should prioritize for future engagement.
#
# Your recommendations should be evidence-based. Use the data to identify patterns in giving, compare potential sources of support, and explain why particular markets or institutions appear especially promising. Support your conclusions with appropriate summaries and visualizations, and translate your findings into a small set of concrete recommendations for the Director of Development.,
#
# 1. In your first .ipynb or .py file called **initial_analysis** complete the following steps:
#      1. Load the Foreign Gifts data.
#      2. Describe the differences between different classes of gift types.
#      3. Answer the following questions:
#          1. Which country gives the most money in total?
#          2. Which country initiates the most gifts by count?
#          3. Which country gives the largest gifts on average?
#          4. Which institution receive the most money in total?
#          5. Which institution receive the greatest number of gifts by count?
#          6. What is the average amount each university receives? Median amount? If they are different why?
#          7. What is the largest flow of a single country to a single institution?
#          8. Which are the top giftors to US academic institutions?
#  2. In a new .ipynb/.py file called **uva_analysis**, analyze foreign giving to UVA. Compare UVA to appropriate peer institutions and the market overall. Propose a strategy for finding new sources of foreign money and provide a quantitative analysis.
#  3. In a document file (.doc, .docx, .pdf, etc.), summarize your findings:
#      1. Executive Summary: What are your main findings and recommendations, in a single paragraph?
#      2. Summarize the results of your initial analyses of overall giving and giving to UVA (1-3 paragraphs).
#      3. Describe a strategy for finding new potential sources of money for UVA. What countries or institutions should UVA target, and why? (1-3 paragraphs)
#      4. Conclude with a summary of UVA's prospects for increasing foreign giving. (1 paragraph).
#
#  In total, your submission repo contain submit at least .ipynb/.py analysis files and a document file with your report (.doc, .docx, .pdf, etc.). If you divide the work among members of a group, make sure that you understand the code being written and submitted by the other members of your group.

# %% [markdown]
# ## The standard stack: importing packages + reading in the data

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

df = pd.read_csv('ForeignGifts_edu.csv',low_memory=False)
df.head()
# Out:
#    ID   OPEID               Institution Name          City State  \
# 0   1  102000  Jacksonville State University  Jacksonville    AL
# 1   2  104700                Troy University          Troy    AL
# 2   3  105100          University of Alabama    Tuscaloosa    AL
# 3   4  105100          University of Alabama    Tuscaloosa    AL
# 4   5  105100          University of Alabama    Tuscaloosa    AL
#
#    Foreign Gift Received Date  Foreign Gift Amount      Gift Type  \
# 0                       43738               250000  Monetary Gift
# 1                       43592               463657       Contract
# 2                       43466              3649107       Contract
# 3                       43472                 1000       Contract
# 4                       43479                49476       Contract
#
#   Country of Giftor                          Giftor Name
# 0             CHINA                                  NaN
# 1             CHINA     Confucius Institute Headquarters
# 2           ENGLAND  Springer Nature Customer Service Ce
# 3      SAUDI ARABIA       Saudi Arabia Education Mission
# 4      SAUDI ARABIA       Saudi Arabia Education Mission

# %% [markdown]
# ## Groupby
#
# As we learned, `.groupby` is a super useful way to aggregate the data and explore summary statistics. We can assign the output to a new dataframe, just taking the n largest amounts. Resetting the index just changes the index to integers starting at 0.
#
# <div class="alert alert-block alert-warning">
# <b>Question 1:</b>  Which country gives the most money, in total?
# </div>

# %% [markdown]
# Qatar gives the most money in total.

# %%
sums = df.groupby(["Country of Giftor"]).sum()
max_gift = sums["Foreign Gift Amount"].max()
sums.loc[sums["Foreign Gift Amount"] == max_gift]
# Out:
#                          ID      OPEID  \
# Country of Giftor
# QATAR              14133760  207860000
#
#                                                     Institution Name  \
# Country of Giftor
# QATAR              Arizona State UniversityArizona State Universi...
#
#                                                                 City  \
# Country of Giftor
# QATAR              TempeTempeTempeTempeTempeTempeTempeTempeTempeT...
#
#                                                                State  \
# Country of Giftor
# QATAR              AZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZAZ...
#
#                    Foreign Gift Received Date  Foreign Gift Amount  \
# Country of Giftor
# QATAR                                29707239           2706240869
#
#                                                            Gift Type  \
# Country of Giftor
# QATAR              ContractContractContractContractContractContra...
#
#                                                          Giftor Name
# Country of Giftor
# QATAR              RasGas Company LimitedRasGas Company LimitedRa...

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Question 2:</b>  Which country initiates the most gifts, by count?
# </div>

# %% [markdown]
# England has the highest gift count.

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Question 3:</b>  Which country gives the largest gifts, on average?
# </div>

# %% [markdown]
# In initial_analysis.ipynb

# %% [markdown]
# ## Ordering by institution
#
# <div class="alert alert-block alert-warning">
# <b>Question 4:</b>  Which institution receive the most money, in total?
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Question 5:</b>  Which institution receive the greatest number of gifts, by count?
# </div>
#
# Build a plot of the top 20 institutions by the amount or number of gifts they have received using either seaborn or plotly.

# %%
top_20_series = df.groupby(["Institution Name"])["Foreign Gift Amount"].sum().sort_values(ascending=False).head(20)
top_20_schools = list(top_20_series.index)
top_20_gifts = list((top_20_series))

top_20_df = pd.DataFrame(data={
    "Institution Name": top_20_schools,
    "Foreign Gift Amount": top_20_gifts
})

top_20_df
# Out:
#                                  Institution Name  Foreign Gift Amount
# 0                      Carnegie Mellon University           1477922504
# 1                              Cornell University           1289937761
# 2                              Harvard University            954803610
# 3           Massachusetts Institute of Technology            859071692
# 4                                 Yale University            613441311
# 5                            Texas A&M University            521455050
# 6                        Johns Hopkins University            502409595
# 7                         Northwestern University            402316221
# 8                           Georgetown University            379950511
# 9                     University of Chicago (The)            364544338
# 10                 University of Colorado Boulder            360173159
# 11                                Duke University            343699498
# 12                       Brigham Young University            323509863
# 13                            Stanford University            319561362
# 14  University of Texas MD Anderson Cancer Center            301527419
# 15              University of Southern California            297018636
# 16    Columbia University in the City of New York            295506012
# 17             University of California, Berkeley            294479904
# 18                     University of Pennsylvania            292730761
# 19             University of Michigan - Ann Arbor            287336783

# %%
plot = px.scatter(top_20_df, x="Institution Name", y="Foreign Gift Amount", title="Foreign Gift Amount received by US Institutions")
plot.show()

# %% [markdown]
# ## Comparing summary statistics
#
# <div class="alert alert-block alert-warning">
# <b>Question 6:</b>  What is the average amount each university receives? Median amount? If they are different, why?
# </div>
#
# Plot a histogram of the amounts received by each university, and then label the median and the mean as vertical lines.

# %%
total_amounts = df.groupby(["Institution Name"], as_index=False)["Foreign Gift Amount"].sum()
totals_mean = total_amounts["Foreign Gift Amount"].mean()
totals_median = total_amounts["Foreign Gift Amount"].median()
total_amounts
# Out:
#                                       Institution Name  Foreign Gift Amount
# 0                                   Adelphi University              1000000
# 1                  Albert Einstein College of Medicine              4252385
# 2                                    Alfred University              2711699
# 3                            American University (The)              3489000
# 4                                      Amherst College               778723
# ..                                                 ...                  ...
# 313                            Wright State University              1693644
# 314                     Xavier University of Louisiana               706193
# 315                                    Yale University            613441311
# 316                                 Yeshiva University               297397
# 317  Young Americans College of the Performing Arts...              1121583
#
# [318 rows x 2 columns]

# %%
totals_median
# Out:
# np.float64(6486791.5)

# %%
totals_hist = px.histogram(total_amounts, x="Foreign Gift Amount")
totals_hist.add_vline(x=totals_mean, line_color = "red", annotation_text="mean")
totals_hist.add_vline(x=totals_median, line_color = "blue", annotation_text="median")
totals_hist.show()

# %% [markdown]
# ## Relationship between variables:
# <div class="alert alert-block alert-warning">
# <b>Question 7:</b>  What is the largest flow of a single country to a single institution? <br> Answer is in initial_analysis.ipynb <br>
# </div>
#
# ### Cross-tabulation
# First, use `pd.crosstab` to look at the relationship between outcoming gifts from countries and incoming gifts to institutions.

# %%
gifting_countries = df.groupby(["Country of Giftor"], as_index=False)["Foreign Gift Amount"].sum()

pd.crosstab(index=total_amounts["Institution Name"], columns=gifting_countries["Country of Giftor"], values=total_amounts["Foreign Gift Amount"], aggfunc='sum')
# Out:
# Country of Giftor                    AFGHANISTAN  AMERICAN SAMOA     ANGOLA  \
# Institution Name
# Adelphi University                     1000000.0             NaN        NaN
# Albert Einstein College of Medicine          NaN       4252385.0        NaN
# Alfred University                            NaN             NaN  2711699.0
# American University (The)                    NaN             NaN        NaN
# Amherst College                              NaN             NaN        NaN
# ...                                          ...             ...        ...
# Oral Roberts University                      NaN             NaN        NaN
# Oregon Health & Science University           NaN             NaN        NaN
# Oregon State University                      NaN             NaN        NaN
# Pace University                              NaN             NaN        NaN
# Pennsylvania State University (The)          NaN             NaN        NaN
#
# Country of Giftor                      ANTIGUA  ARGENTINA  ARMENIA  AUSTRALIA  \
# Institution Name
# Adelphi University                         NaN        NaN      NaN        NaN
# Albert Einstein College of Medicine        NaN        NaN      NaN        NaN
# Alfred University                          NaN        NaN      NaN        NaN
# American University (The)            3489000.0        NaN      NaN        NaN
# Amherst College                            NaN   778723.0      NaN        NaN
# ...                                        ...        ...      ...        ...
# Oral Roberts University                    NaN        NaN      NaN        NaN
# Oregon Health & Science University         NaN        NaN      NaN        NaN
# Oregon State University                    NaN        NaN      NaN        NaN
# Pace University                            NaN        NaN      NaN        NaN
# Pennsylvania State University (The)        NaN        NaN      NaN        NaN
#
# Country of Giftor                    AUSTRIA  AZERBAIJAN  BAHAMAS  ...  \
# Institution Name                                                   ...
# Adelphi University                       NaN         NaN      NaN  ...
# Albert Einstein College of Medicine      NaN         NaN      NaN  ...
# Alfred University                        NaN         NaN      NaN  ...
# American University (The)                NaN         NaN      NaN  ...
# Amherst College                          NaN         NaN      NaN  ...
# ...                                      ...         ...      ...  ...
# Oral Roberts University                  NaN         NaN      NaN  ...
# Oregon Health & Science University       NaN         NaN      NaN  ...
# Oregon State University                  NaN         NaN      NaN  ...
# Pace University                          NaN         NaN      NaN  ...
# Pennsylvania State University (The)      NaN         NaN      NaN  ...
#
# Country of Giftor                    UNITED NATIONS  URUGUAY  USA  VENEZUELA  \
# Institution Name
# Adelphi University                              NaN      NaN  NaN        NaN
# Albert Einstein College of Medicine             NaN      NaN  NaN        NaN
# Alfred University                               NaN      NaN  NaN        NaN
# American University (The)                       NaN      NaN  NaN        NaN
# Amherst College                                 NaN      NaN  NaN        NaN
# ...                                             ...      ...  ...        ...
# Oral Roberts University                         NaN      NaN  NaN        NaN
# Oregon Health & Science University              NaN      NaN  NaN        NaN
# Oregon State University                         NaN      NaN  NaN        NaN
# Pace University                                 NaN      NaN  NaN        NaN
# Pennsylvania State University (The)             NaN      NaN  NaN        NaN
#
# Country of Giftor                    VIETNAM  VIRGIN ISLANDS (BRITISH)  \
# Institution Name
# Adelphi University                       NaN                       NaN
# Albert Einstein College of Medicine      NaN                       NaN
# Alfred University                        NaN                       NaN
# American University (The)                NaN                       NaN
# Amherst College                          NaN                       NaN
# ...                                      ...                       ...
# Oral Roberts University                  NaN                  764059.0
# Oregon Health & Science University       NaN                       NaN
# Oregon State University                  NaN                       NaN
# Pace University                          NaN                       NaN
# Pennsylvania State University (The)      NaN                       NaN
#
# Country of Giftor                         WALES       YEMEN     ZAMBIA  \
# Institution Name
# Adelphi University                          NaN         NaN        NaN
# Albert Einstein College of Medicine         NaN         NaN        NaN
# Alfred University                           NaN         NaN        NaN
# American University (The)                   NaN         NaN        NaN
# Amherst College                             NaN         NaN        NaN
# ...                                         ...         ...        ...
# Oral Roberts University                     NaN         NaN        NaN
# Oregon Health & Science University   51804595.0         NaN        NaN
# Oregon State University                     NaN  26357408.0        NaN
# Pace University                             NaN         NaN  2264746.0
# Pennsylvania State University (The)         NaN         NaN        NaN
#
# Country of Giftor                      ZIMBABWE
# Institution Name
# Adelphi University                          NaN
# Albert Einstein College of Medicine         NaN
# Alfred University                           NaN
# American University (The)                   NaN
# Amherst College                             NaN
# ...                                         ...
# Oral Roberts University                     NaN
# Oregon Health & Science University          NaN
# Oregon State University                     NaN
# Pace University                             NaN
# Pennsylvania State University (The)  43458897.0
#
# [155 rows x 155 columns]

# %% [markdown]
# ### Flow of information using alluvial plots
#
# To better visualize which countries money is flowing from and which institutions it is flowing into, we can use an alluvial diagram. There is a built-in version in plotly that we'll use.

# %%
import plotly.graph_objects as go

# giftor = 'Giftor Name'
# recipi = 'Institution Name'
# flor = 'Foreign Gift Amount'

giftor = 'Giftor Name'
recipi = 'Institution Name'
flow = 'Foreign Gift Amount'
N = 20

flows = (
    df.groupby([giftor, 
                recipi])
      [flow]
      .sum()
      .nlargest(N)
      .reset_index()
)

labels = (
    flows[giftor].tolist()
    + flows[recipi].tolist()
)

labels = list(dict.fromkeys(labels))

fig = go.Figure(
    go.Sankey(
        node=dict(label=labels),
        link=dict(
            source=flows[giftor]
                        .map(labels.index),
            target=flows[recipi]
                        .map(labels.index),
            value=flows[flow]
        )
    )
)

fig.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
# <b>Question 8:</b>  Which are the top giftors to US academic institutions?
# </div>

# %% [markdown]
# Qatar Foundation and its 2 branches/sub-organizations are the top giftors to US institutions.
